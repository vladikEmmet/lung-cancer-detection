# %% [markdown]
# # 10 — Histology ResNet50 (pretrained + scratch)
#
# Both transfer learning variants in one notebook (LC25000 is fast enough). Saves two JSON files for the aggregation step.

# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

import pandas as pd
import yaml

from utils.seed import set_seed
from utils.models import build_resnet50
from utils.data_histology import LC25000Dataset, get_transforms
from utils.training import train_dl_cv, save_fold_results
from utils.metrics import aggregate_folds
from utils.stats import format_results_table

with open('../configs/histology.yaml') as f:
    cfg = yaml.safe_load(f)
set_seed(cfg['seed'])

cache_dir = Path('..') / cfg['data']['cache_dir']
labels_df = pd.read_csv(cache_dir / 'labels.csv')
y = labels_df['label_binary'].to_numpy().astype(int)
print('samples:', len(labels_df), 'pos rate:', y.mean())
# Out:
# samples: 3000 pos rate: 0.6666666666666666

# %%
train_tf, eval_tf = get_transforms(cfg['data']['image_size'])
dataset = LC25000Dataset(labels_df, transform=eval_tf, label_col='label_binary')

results_dir = Path('..') / cfg['paths']['results']
results_dir.mkdir(parents=True, exist_ok=True)

summary = {}

for tag, pretrained in [('pretrained', True), ('scratch', False)]:
    print(f'\n=== ResNet50 ({tag}) ===')

    def model_fn(_p=pretrained):
        return build_resnet50(pretrained=_p, num_classes=1)

    folds = train_dl_cv(
        dataset=dataset,
        model_fn=model_fn,
        labels=y,
        n_splits=cfg['cv']['n_splits'],
        seed=cfg['seed'],
        epochs=cfg['dl']['epochs'],
        batch_size=cfg['dl']['batch_size'],
        lr=cfg['dl']['lr'],
        weight_decay=cfg['dl']['weight_decay'],
        patience=cfg['dl']['patience'],
        num_workers=cfg['dl']['num_workers'],
        device='auto',
        augment_train=train_tf,
        augment_eval=eval_tf,
        verbose=True,
    )
    save_fold_results(folds, results_dir / f'histology_ResNet50_{tag}.json')
    summary[f'ResNet50_{tag}'] = aggregate_folds([f.metrics_calibrated for f in folds])

format_results_table(summary)
# Out:
# === ResNet50 (pretrained) ===
# [fold 0] train=2400 test=600 pos_train=1600 pos_test=400
# Python(59895) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(59904) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(59905) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(59908) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(60597) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(60607) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(60609) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(60618) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  1/30 loss=0.1038 val_auc=1.0000
# Python(60860) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(60874) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(60877) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(60886) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(61701) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(61710) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(61711) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(61720) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  2/30 loss=0.0135 val_auc=1.0000
# Python(61877) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(61886) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(61887) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(61888) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(62467) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(62477) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(62481) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(62483) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  3/30 loss=0.0064 val_auc=1.0000
# Python(62646) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(62655) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(62656) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(62665) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(63336) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(63345) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(63346) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(63359) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  4/30 loss=0.0029 val_auc=1.0000
# Python(63598) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(63607) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(63608) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(63617) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(64317) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(64327) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(64328) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(64329) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  5/30 loss=0.0048 val_auc=1.0000
# Python(64487) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(64497) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(64500) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(64509) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(65174) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(65187) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(65198) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(65201) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  6/30 loss=0.0054 val_auc=1.0000
#   early stop at epoch 6 (patience=5)
# Python(65423) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(65432) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(65437) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(65449) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(65597) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(65607) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(65608) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(65617) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [fold 0] AUC=1.0000 thr=0.439 BalAcc(cal)=1.000
# [fold 1] train=2400 test=600 pos_train=1600 pos_test=400
# Python(65879) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(65880) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(65892) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(65893) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66651) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66663) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66666) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66671) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  1/30 loss=0.0994 val_auc=1.0000
# Python(66862) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66871) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66872) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(66881) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67596) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67597) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67608) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67609) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  2/30 loss=0.0174 val_auc=1.0000
# Python(67792) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67801) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67811) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(67813) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(68705) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(68716) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(68726) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(68728) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  3/30 loss=0.0059 val_auc=1.0000
# Python(68889) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(68898) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(68907) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(68908) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(69615) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(69625) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(69627) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(69638) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  4/30 loss=0.0022 val_auc=1.0000
# Python(69792) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(69801) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(69802) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(69803) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(70430) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(70431) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(70440) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(70441) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  5/30 loss=0.0040 val_auc=1.0000
# Python(70623) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(70626) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(70635) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(70636) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71518) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71528) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71539) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71540) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  6/30 loss=0.0015 val_auc=1.0000
#   early stop at epoch 6 (patience=5)
# Python(71708) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71718) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71729) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71730) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71892) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71901) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71910) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(71911) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [fold 1] AUC=1.0000 thr=0.539 BalAcc(cal)=0.999
# [fold 2] train=2400 test=600 pos_train=1600 pos_test=400
# Python(72378) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72387) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72389) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(72399) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(73176) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(73186) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(73187) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(73196) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  1/30 loss=0.1043 val_auc=1.0000
# Python(73389) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(73390) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(73399) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(73403) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(74216) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(74227) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(74237) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(74239) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  2/30 loss=0.0093 val_auc=1.0000
# Python(74427) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(74436) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(74437) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(74438) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(75083) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(75084) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(75094) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(75098) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  3/30 loss=0.0078 val_auc=1.0000
# Python(75339) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(75341) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(75350) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(75356) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(76136) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(76145) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(76146) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(76155) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  4/30 loss=0.0079 val_auc=1.0000
# Python(76331) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(76341) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(76345) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(76357) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(77216) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(77226) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(77227) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(77228) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  5/30 loss=0.0040 val_auc=1.0000
# Python(77427) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(77436) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(77438) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(77439) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(78436) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(78445) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(78447) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(78457) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  6/30 loss=0.0029 val_auc=1.0000
#   early stop at epoch 6 (patience=5)
# Python(78637) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(78638) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(78648) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(78649) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(78815) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(78817) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(78828) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(78829) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [fold 2] AUC=1.0000 thr=0.747 BalAcc(cal)=0.995
# [fold 3] train=2400 test=600 pos_train=1600 pos_test=400
# Python(79118) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(79130) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(79141) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(79145) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(79971) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(79982) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(79991) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(79994) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  1/30 loss=0.1057 val_auc=1.0000
# Python(80213) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(80214) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(80223) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(80224) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(80966) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(80977) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(80978) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(80988) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  2/30 loss=0.0092 val_auc=1.0000
# Python(81130) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(81139) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(81140) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(81149) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(81928) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(81938) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(81949) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(81951) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  3/30 loss=0.0072 val_auc=1.0000
# Python(82179) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(82189) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(82190) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(82199) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(83139) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(83152) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(83161) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(83163) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  4/30 loss=0.0042 val_auc=1.0000
# Python(83358) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(83367) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(83369) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(83371) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(84179) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(84188) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(84189) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(84198) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  5/30 loss=0.0027 val_auc=1.0000
# Python(84377) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(84387) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(84396) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(84397) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(85334) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(85349) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(85350) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(85361) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  6/30 loss=0.0009 val_auc=1.0000
#   early stop at epoch 6 (patience=5)
# Python(85513) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(85522) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(85523) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(85532) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(85712) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(85721) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(85722) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(85723) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [fold 3] AUC=1.0000 thr=0.482 BalAcc(cal)=1.000
# [fold 4] train=2400 test=600 pos_train=1600 pos_test=400
# Python(86021) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(86022) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(86031) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(86032) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(87218) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(87220) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(87230) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(87231) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  1/30 loss=0.1008 val_auc=1.0000
# Python(87423) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(87434) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(87435) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(87445) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(88367) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(88377) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(88386) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(88387) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  2/30 loss=0.0151 val_auc=1.0000
# Python(88566) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(88567) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(88577) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(88578) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(89477) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(89491) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(89493) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(89504) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  3/30 loss=0.0055 val_auc=1.0000
# Python(89801) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(89811) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(89812) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(89822) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(90832) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(90841) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(90842) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(90852) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  4/30 loss=0.0072 val_auc=1.0000
# Python(91061) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(91071) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(91080) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(91081) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(92103) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(92104) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(92114) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(92117) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  5/30 loss=0.0026 val_auc=1.0000
# Python(92317) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(92327) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(92328) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(92339) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(93486) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(93495) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(93496) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(93505) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  6/30 loss=0.0009 val_auc=1.0000
#   early stop at epoch 6 (patience=5)
# Python(93839) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(93840) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(93849) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(93850) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(94037) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(94046) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(94055) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(94056) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [fold 4] AUC=1.0000 thr=0.705 BalAcc(cal)=1.000
#
# === ResNet50 (scratch) ===
# [fold 0] train=2400 test=600 pos_train=1600 pos_test=400
# Python(94357) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(94366) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(94370) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(94379) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(95247) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(95261) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(95271) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(95272) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  1/30 loss=0.1004 val_auc=0.9994
# Python(95450) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(95459) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(95460) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(95469) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(96218) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(96230) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(96231) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(96234) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  2/30 loss=0.0341 val_auc=0.9995
# Python(96417) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(96418) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(96428) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(96429) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(97102) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(97111) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(97112) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(97122) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  3/30 loss=0.0302 val_auc=0.9999
# Python(97315) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(97316) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(97327) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(97331) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(98115) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(98116) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(98126) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(98127) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  4/30 loss=0.0281 val_auc=1.0000
# Python(98462) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(98471) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(98473) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(98483) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(99425) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(99438) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(99458) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(99476) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  5/30 loss=0.0310 val_auc=0.9991
# Python(99715) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(99724) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(99725) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(99734) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(755) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(775) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(792) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(798) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  6/30 loss=0.0423 val_auc=0.9999
# Python(1116) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(1125) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(1126) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(1135) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(1961) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(1970) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(1972) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(1982) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  7/30 loss=0.0187 val_auc=1.0000
# Python(2208) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(2219) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(2221) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(2231) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(2942) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(2957) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(2960) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(2970) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  8/30 loss=0.0243 val_auc=1.0000
#   early stop at epoch 8 (patience=5)
# Python(3146) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(3147) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(3156) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(3157) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(3332) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(3342) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(3343) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(3353) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [fold 0] AUC=0.9999 thr=0.491 BalAcc(cal)=0.994
# [fold 1] train=2400 test=600 pos_train=1600 pos_test=400
# Python(3656) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(3667) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(3673) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(3677) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(4442) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(4452) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(4453) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(4464) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  1/30 loss=0.1253 val_auc=0.9993
# Python(4680) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(4681) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(4690) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(4692) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(5472) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(5489) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(5490) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(5493) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  2/30 loss=0.0511 val_auc=0.9996
# Python(5706) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(5711) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(5720) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(5722) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(6604) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(6613) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(6614) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(6625) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  3/30 loss=0.0365 val_auc=0.9997
# Python(6831) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(6832) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(6841) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(6842) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(7697) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(7706) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(7719) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(7722) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  4/30 loss=0.0380 val_auc=0.9999
# Python(7904) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(7914) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(7915) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(7916) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(8732) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(8750) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(8751) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(8755) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  5/30 loss=0.0185 val_auc=0.9999
# Python(8946) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(8955) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(8964) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(8965) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(9755) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(9764) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(9765) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(9775) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  6/30 loss=0.0190 val_auc=0.9998
# Python(9984) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(9993) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(10004) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(10005) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(10832) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(10841) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(10842) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(10844) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  7/30 loss=0.0159 val_auc=0.9999
# Python(11033) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(11034) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(11044) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(11046) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(11932) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(11942) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(11943) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(11953) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  8/30 loss=0.0323 val_auc=0.9998
# Python(12156) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(12165) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(12166) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(12177) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(13085) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(13087) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(13097) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(13098) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  9/30 loss=0.0123 val_auc=0.9999
#   early stop at epoch 9 (patience=5)
# Python(13345) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(13355) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(13356) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(13366) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(13535) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(13544) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(13545) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(13546) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [fold 1] AUC=0.9999 thr=0.605 BalAcc(cal)=0.990
# [fold 2] train=2400 test=600 pos_train=1600 pos_test=400
# Python(13922) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(13935) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(13938) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(13947) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(14760) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(14769) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(14770) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(14771) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  1/30 loss=0.1060 val_auc=0.9990
# Python(15002) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(15011) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(15012) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(15013) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(15946) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(15956) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(15965) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(15966) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  2/30 loss=0.0424 val_auc=0.9995
# Python(16167) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(16176) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(16177) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(16178) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(17034) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(17046) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(17050) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(17061) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  3/30 loss=0.0335 val_auc=0.9995
# Python(17262) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(17275) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# ...
# Python(28650) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(28663) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  2/30 loss=0.0529 val_auc=0.9997
# Python(28854) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(28855) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(28864) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(28865) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(29819) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(29828) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(29830) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(29839) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  3/30 loss=0.0363 val_auc=0.9993
# Python(30037) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(30056) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(30057) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(30058) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(31051) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(31062) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(31063) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(31064) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  4/30 loss=0.0250 val_auc=1.0000
# Python(31316) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(31328) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(31329) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(31331) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(32553) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(32566) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(32568) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(32569) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  5/30 loss=0.0198 val_auc=0.9987
# Python(32831) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(32841) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(32842) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(32851) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(33803) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(33812) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(33813) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(33822) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  6/30 loss=0.0221 val_auc=1.0000
# Python(34059) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(34106) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(34110) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(34122) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(35140) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(35153) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(35156) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(35160) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  7/30 loss=0.0284 val_auc=1.0000
# Python(35355) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(35356) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(35365) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(35367) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(36336) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(36347) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(36348) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(36349) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  8/30 loss=0.0139 val_auc=1.0000
# Python(36539) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(36549) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(36550) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(36559) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(37591) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(37600) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(37602) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(37603) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  9/30 loss=0.0123 val_auc=1.0000
#   early stop at epoch 9 (patience=5)
# Python(37783) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(37785) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(37796) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(37798) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(37974) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(37983) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(37992) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(37993) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [fold 3] AUC=1.0000 thr=0.251 BalAcc(cal)=0.996
# [fold 4] train=2400 test=600 pos_train=1600 pos_test=400
# Python(38416) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(38417) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(38427) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(38429) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(39484) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(39494) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(39504) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(39508) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  1/30 loss=0.0903 val_auc=0.9994
# Python(39714) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(39723) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(39724) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(39725) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(40985) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(40995) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(40996) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(40997) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  2/30 loss=0.0446 val_auc=0.9996
# Python(41190) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(41199) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(41208) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(41209) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(42288) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(42299) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(42302) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(42307) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  3/30 loss=0.0378 val_auc=0.9996
# Python(42555) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(42564) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(42573) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(42575) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(43778) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(43796) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(43797) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(43798) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  4/30 loss=0.0312 val_auc=1.0000
# Python(44051) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(44052) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(44062) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(44067) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(45303) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(45316) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(45335) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(45342) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  5/30 loss=0.0251 val_auc=1.0000
# Python(45550) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(45567) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(45576) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(45577) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(46839) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(46850) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(46851) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(46852) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  6/30 loss=0.0206 val_auc=1.0000
# Python(47072) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(47089) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(47090) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(47091) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(48386) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(48399) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(48410) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(48421) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  7/30 loss=0.0143 val_auc=1.0000
# Python(48672) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(48688) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(48700) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(48701) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50269) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50282) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50292) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50296) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  8/30 loss=0.0157 val_auc=1.0000
# Python(50571) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50581) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50590) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(50591) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(52152) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(52167) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(52177) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(52179) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
#   epoch  9/30 loss=0.0146 val_auc=1.0000
#   early stop at epoch 9 (patience=5)
# Python(52390) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(52400) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(52409) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(52410) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(52689) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(52690) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(52699) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Python(52701) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# [fold 4] AUC=1.0000 thr=0.965 BalAcc(cal)=1.000
#                           accuracy    sensitivity    specificity  \
# model
# ResNet50_pretrained  0.998 ± 0.003  0.997 ± 0.004  1.000 ± 0.000
# ResNet50_scratch     0.995 ± 0.004  0.995 ± 0.006  0.996 ± 0.004
#
#                          precision             f1 balanced_accuracy  \
# model
# ResNet50_pretrained  1.000 ± 0.000  0.999 ± 0.002     0.999 ± 0.002
# ResNet50_scratch     0.998 ± 0.002  0.996 ± 0.003     0.995 ± 0.004
#
#                            auc_roc         pr_auc
# model
# ResNet50_pretrained  1.000 ± 0.000  1.000 ± 0.000
# ResNet50_scratch     1.000 ± 0.000  1.000 ± 0.000
